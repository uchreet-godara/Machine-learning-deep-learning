# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# You are using pip version 19.0.3, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Done.

# %%
from fastai import *
from fastai.vision import *
import matplotlib.pyplot as plt

# %%
help(untar_data)
# Out:
# Help on function untar_data in module fastai.datasets:
#
# untar_data(url:str, fname:Union[pathlib.Path, str]=None, dest:Union[pathlib.Path, str]=None, data=True, force_download=False) -> pathlib.Path
#     Download `url` to `fname` if `dest` doesn't exist, and un-tgz to folder `dest`.

# %%
path = untar_data(URLs.PETS)

# %%
path
# Out:
# PosixPath('/tmp/.fastai/data/oxford-iiit-pet')

# %%
path.ls()
# Out:
# [PosixPath('/tmp/.fastai/data/oxford-iiit-pet/annotations'),
#  PosixPath('/tmp/.fastai/data/oxford-iiit-pet/images')]

# %%
path_anno = path/'annotations'
path_image = path/'images'

# %%
fnames = get_image_files(path_image)
fnames[:5]
# Out:
# [PosixPath('/tmp/.fastai/data/oxford-iiit-pet/images/japanese_chin_10.jpg'),
#  PosixPath('/tmp/.fastai/data/oxford-iiit-pet/images/Bombay_139.jpg'),
#  PosixPath('/tmp/.fastai/data/oxford-iiit-pet/images/american_bulldog_53.jpg'),
#  PosixPath('/tmp/.fastai/data/oxford-iiit-pet/images/japanese_chin_185.jpg'),
#  PosixPath('/tmp/.fastai/data/oxford-iiit-pet/images/boxer_153.jpg')]

# %%
np.random.seed(2)
pat = r'/([^/]+)_\d+.jpg$'

# %%
data = ImageDataBunch.from_name_re(path_image, fnames, pat, ds_tfms=get_transforms(), size=224)
data.normalize(imagenet_stats)
# Out:
# ImageDataBunch;
#
# Train: LabelList (5912 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# japanese_chin,Bombay,american_bulldog,scottish_terrier,Bengal
# Path: /tmp/.fastai/data/oxford-iiit-pet/images;
#
# Valid: LabelList (1478 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# havanese,Ragdoll,shiba_inu,german_shorthaired,scottish_terrier
# Path: /tmp/.fastai/data/oxford-iiit-pet/images;
#
# Test: None

# %%
data.show_batch(row=3, figsize=(6,7))
# Out:
# /opt/conda/lib/python3.6/site-packages/matplotlib/tight_layout.py:199: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   warnings.warn('Tight layout not applied. '

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['Abyssinian', 'Bengal', 'Birman', 'Bombay', 'British_Shorthair', 'Egyptian_Mau', 'Maine_Coon', 'Persian', 'Ragdoll', 'Russian_Blue', 'Siamese', 'Sphynx', 'american_bulldog', 'american_pit_bull_terrier', 'basset_hound', 'beagle', 'boxer', 'chihuahua', 'english_cocker_spaniel', 'english_setter', 'german_shorthaired', 'great_pyrenees', 'havanese', 'japanese_chin', 'keeshond', 'leonberger', 'miniature_pinscher', 'newfoundland', 'pomeranian', 'pug', 'saint_bernard', 'samoyed', 'scottish_terrier', 'shiba_inu', 'staffordshire_bull_terrier', 'wheaten_terrier', 'yorkshire_terrier']
# (37, 37)

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /tmp/.torch/models/resnet50-19c8e357.pth
# 102502400it [00:01, 100051483.30it/s]

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.858730</td>
#       <td>0.255878</td>
#       <td>0.087957</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.415925</td>
#       <td>0.213792</td>
#       <td>0.071719</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.259459</td>
#       <td>0.181726</td>
#       <td>0.063599</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.170290</td>
#       <td>0.156038</td>
#       <td>0.048714</td>
#       <td>01:21</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
interp=ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
doc(interp.plot_top_losses)

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('Egyptian_Mau', 'Bengal', 5),
#  ('Ragdoll', 'Birman', 4),
#  ('Bengal', 'Egyptian_Mau', 3),
#  ('Birman', 'Ragdoll', 3),
#  ('beagle', 'basset_hound', 3),
#  ('staffordshire_bull_terrier', 'american_pit_bull_terrier', 3),
#  ('Bengal', 'Abyssinian', 2),
#  ('Birman', 'Siamese', 2),
#  ('Persian', 'Ragdoll', 2),
#  ('Russian_Blue', 'British_Shorthair', 2),
#  ('american_bulldog', 'american_pit_bull_terrier', 2),
#  ('american_pit_bull_terrier', 'boxer', 2),
#  ('american_pit_bull_terrier', 'staffordshire_bull_terrier', 2),
#  ('chihuahua', 'miniature_pinscher', 2),
#  ('german_shorthaired', 'beagle', 2),
#  ('havanese', 'wheaten_terrier', 2),
#  ('miniature_pinscher', 'american_pit_bull_terrier', 2),
#  ('miniature_pinscher', 'chihuahua', 2),
#  ('shiba_inu', 'samoyed', 2)]

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.482160</td>
#       <td>0.352879</td>
#       <td>0.114344</td>
#       <td>01:25</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('stage-1')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (5912 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# japanese_chin,Bombay,american_bulldog,scottish_terrier,Bengal
# Path: /tmp/.fastai/data/oxford-iiit-pet/images;
#
# Valid: LabelList (1478 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# havanese,Ragdoll,shiba_inu,german_shorthaired,scottish_terrier
# Path: /tmp/.fastai/data/oxford-iiit-pet/images;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
# ...

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.149643</td>
#       <td>0.154496</td>
#       <td>0.050068</td>
#       <td>01:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.140905</td>
#       <td>0.154089</td>
#       <td>0.050068</td>
#       <td>01:25</td>
#     </tr>
#   </tbody>
# </table>

# %%
data = ImageDataBunch.from_name_re(path_image, fnames, pat, ds_tfms=get_transforms(), size=299, bs=48)
data.normalize(imagenet_stats)
# Out:
# ImageDataBunch;
#
# Train: LabelList (5912 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# japanese_chin,Bombay,american_bulldog,japanese_chin,scottish_terrier
# Path: /tmp/.fastai/data/oxford-iiit-pet/images;
#
# Valid: LabelList (1478 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# newfoundland,shiba_inu,Birman,scottish_terrier,Persian
# Path: /tmp/.fastai/data/oxford-iiit-pet/images;
#
# Test: None

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate)

# %%
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.765365</td>
#       <td>0.263070</td>
#       <td>0.082544</td>
#       <td>02:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.366529</td>
#       <td>0.199303</td>
#       <td>0.069012</td>
#       <td>01:56</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.262811</td>
#       <td>0.178974</td>
#       <td>0.054804</td>
#       <td>01:56</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.170318</td>
#       <td>0.161429</td>
#       <td>0.052774</td>
#       <td>01:56</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.131606</td>
#       <td>0.153343</td>
#       <td>0.052774</td>
#       <td>01:56</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-50')

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(1, max_lr=slice(1e-5,1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.242747</td>
#       <td>0.243709</td>
#       <td>0.076455</td>
#       <td>02:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('stage-1-50')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (5912 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# japanese_chin,Bombay,american_bulldog,japanese_chin,scottish_terrier
# Path: /tmp/.fastai/data/oxford-iiit-pet/images;
#
# Valid: LabelList (1478 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# newfoundland,shiba_inu,Birman,scottish_terrier,Persian
# Path: /tmp/.fastai/data/oxford-iiit-pet/images;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.most_confused(min_val=2)
# Out:
# [('Ragdoll', 'Birman', 4),
#  ('staffordshire_bull_terrier', 'american_pit_bull_terrier', 4),
#  ('Maine_Coon', 'Persian', 3),
#  ('american_pit_bull_terrier', 'staffordshire_bull_terrier', 3),
#  ('beagle', 'basset_hound', 3),
#  ('boxer', 'american_bulldog', 3),
#  ('Birman', 'Ragdoll', 2),
#  ('British_Shorthair', 'Ragdoll', 2),
#  ('Egyptian_Mau', 'Bengal', 2),
#  ('Russian_Blue', 'British_Shorthair', 2),
#  ('american_bulldog', 'american_pit_bull_terrier', 2),
#  ('american_bulldog', 'staffordshire_bull_terrier', 2),
#  ('basset_hound', 'beagle', 2),
#  ('english_cocker_spaniel', 'english_setter', 2),
#  ('english_setter', 'english_cocker_spaniel', 2),
#  ('staffordshire_bull_terrier', 'american_bulldog', 2),
#  ('staffordshire_bull_terrier', 'beagle', 2),
#  ('yorkshire_terrier', 'scottish_terrier', 2)]
